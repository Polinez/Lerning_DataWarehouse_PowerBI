# %% [markdown]
# # Download kaggle dataset

# %% [markdown]
# ## Install kaggle library

# %%
# %pip install kaggle
# Out:
# ...
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# ## Set up Kaggle API credentials

# %%
import os

os.environ['KAGGLE_KEY'] = dbutils.secrets.get(scope="kaggle_scope", key="key")

# %% [markdown]
# ## Download the dataset

# %%
volume_path = "/Volumes/brazilian_e_commerce/row_data/row"

# !kaggle datasets download -d olistbr/brazilian-ecommerce -p {volume_path} --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce
# License(s): CC-BY-NC-SA-4.0
# ...
# 100%|██████████████████████████████████████| 42.6M/42.6M [00:00<00:00, 54.0MB/s]

# %% [markdown]
# ## Check if data was correctly extracted

# %%
# List and display the contents of the volume
files_in_volume = dbutils.fs.ls(volume_path)
display(files_in_volume)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
