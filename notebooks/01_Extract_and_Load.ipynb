# %% [markdown]
# # Install kaggle library

# %%
# %pip install kaggle
# Out:
# Requirement already satisfied: kaggle in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ffde4587-1816-4b40-b2b2-8e5872e6e5d6/lib/python3.12/site-packages (2.0.1)
# Requirement already satisfied: bleach in /databricks/python3/lib/python3.12/site-packages (from kaggle) (6.2.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.17 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ffde4587-1816-4b40-b2b2-8e5872e6e5d6/lib/python3.12/site-packages (from kaggle) (0.1.18)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from kaggle) (24.2)
# Requirement already satisfied: protobuf in /databricks/python3/lib/python3.12/site-packages (from kaggle) (5.29.4)
# Requirement already satisfied: python-dateutil in /databricks/python3/lib/python3.12/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ffde4587-1816-4b40-b2b2-8e5872e6e5d6/lib/python3.12/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /databricks/python3/lib/python3.12/site-packages (from kaggle) (2.32.3)
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.12/site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in /databricks/python3/lib/python3.12/site-packages (from kaggle) (2.3.0)
# Requirement already satisfied: webencodings in /databricks/python3/lib/python3.12/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.12/site-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-ffde4587-1816-4b40-b2b2-8e5872e6e5d6/lib/python3.12/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.12/site-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.12/site-packages (from requests->kaggle) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.12/site-packages (from requests->kaggle) (2025.4.26)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# # Set up Kaggle API credentials

# %%
import os

os.environ['KAGGLE_KEY'] = dbutils.secrets.get(scope="kaggle_scope", key="key")

# %% [markdown]
# # Download the dataset

# %%
volume_path = "/Volumes/workspace/default/e2eproject"

# !kaggle datasets download -d olistbr/brazilian-ecommerce -p {volume_path} --unzip
# Out:
# Dataset URL: https://www.kaggle.com/datasets/olistbr/brazilian-ecommerce
# License(s): CC-BY-NC-SA-4.0
# Downloading brazilian-ecommerce.zip to /Volumes/workspace/default/e2eproject
# 100%|██████████████████████████████████████| 42.6M/42.6M [00:00<00:00, 75.7MB/s]

# %% [markdown]
# # Check if data was correctly extracted

# %%
# List and display the contents of the volume
files_in_volume = dbutils.fs.ls(volume_path)
display(files_in_volume)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/Volumes/workspace/default/e2eproject/olist_customers_dataset.csv</td><td>olist_customers_dataset.csv</td><td>9033957</td><td>1776335227000</td></tr><tr><td>dbfs:/Volumes/workspace/default/e2eproject/olist_geolocation_dataset.csv</td><td>olist_geolocation_dataset.csv</td><td>61273883</td><td>1776335227000</td></tr><tr><td>dbfs:/Volumes/workspace/default/e2eproject/olist_order_items_dataset.csv</td><td>olist_order_items_dataset.csv</td><td>15438671</td><td>1776335228000</td></tr><tr><td>dbfs:/Volumes/workspace/default/e2eproject/olist_order_payments_dataset.csv</td><td>olist_order_payments_dataset.csv</td><td>5777138</td><td>1776335228000</td></tr><tr><td>dbfs:/Volumes/workspace/default/e2eproject/olist_order_reviews_dataset.csv</td><td>olist_order_reviews_dataset.csv</td><td>14451670</td><td>1776335229000</td></tr><tr><td>dbfs:/Volumes/workspace/default/e2eproject/olist_orders_dataset.csv</td><td>olist_orders_dataset.csv</td><td>17654914</td><td>1776335229000</td></tr><tr><td>dbfs:/Volumes/workspace/default/e2eproject/olist_products_dataset.csv</td><td>olist_products_dataset.csv</td><td>2379446</td><td>1776335229000</td></tr><tr><td>dbfs:/Volumes/workspace/default/e2eproject/olist_sellers_dataset.csv</td><td>olist_sellers_dataset.csv</td><td>174703</td><td>1776335230000</td></tr><tr><td>dbfs:/Volumes/workspace/default/e2eproject/product_category_name_translation.csv</td><td>product_category_name_translation.csv</td><td>2613</td><td>1776335230000</td></tr></tbody></table></div>
